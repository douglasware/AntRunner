# %% [markdown]
# ## Cat Facts
# This notebook shows how to create, run, and use output from the Cat Facts assistant! This assistant uses a free demonstration web service with no authentication.
#
# The assistant definition enables Code Interpreter which the assistant uses to create a file which is downloaded in the last step.
#
# ## First steps
# - First, download AntRunLib from Nuget
# - At least once, set up the environment using **[0-AI-settings](0-AI-settings.ipynb)**

# %%
#r "nuget: AntRunnerLib, 0.9.6"

using AntRunnerLib;
using AntRunnerLib.Identity;
using static AntRunnerLib.ClientUtility;
using System.IO;

#!import config/Settings.cs 

var envVariables = Settings.GetEnvironmentVariables();
foreach (var kvp in envVariables)
{
    Environment.SetEnvironmentVariable(kvp.Key, kvp.Value);
}

var config = AzureOpenAiConfigFactory.Get();
var client = GetOpenAiClient(config);
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>AntRunnerLib, 0.9.6</span></li></ul></div></div>

# %% [markdown]
# ## List the assistants in your deployment
# If you get an error, verify your setup!

# %%
var assistants = (await client.AssistantList()).Data;
foreach(var assistant in assistants)
{
    Console.WriteLine(assistant.Name);
}
# Out:
# State_DOE_AI_Guides
# LocalCodeTool
# ConversationUserProxy
# Web Ants
# OneDrive Ants
# Note Ants
# Mail Ants
# Guide Ants
# Code Ants
# Chat Ants

# %%
var assistant = (await client.AssistantList())?.Data?.FirstOrDefault(o => o.Name == "Cat Facts");
if(assistant != null) {
    await client.AssistantDelete(assistant.Id);
    Console.WriteLine("Deleted assistant");
}
else
{
    Console.WriteLine("Didn't find cat facts");
}
# Out:
# Didn't find cat facts

# %% [markdown]
# ## Create the Cat Facts assistant
# The definition of this assistant is located in the ".\AssistantDefinitions\Cat Facts" folder
#
# ".\AssistantDefinitions\" is a default path. You can override it by setting the **ASSISTANTS_BASE_FOLDER_PATH** environment variable.
#
# "Cat Facts" contains the following files:
# ```
# Cat Facts
# │   instructions.md - The assistant's instructions. This file is optional but when present overwrites the value of the instructions property in manifest.json
# │   manifest.json - The assistants base settings including model, "model": "gpt-4o". You need to ensure you have deployed whatever models your assistants require
# │
# └───OpenAPI
#         cat-fact.herokuapp.com.json - The swagger definition for the test service
#
# ```
#
# [See https://github.com/alexwohlbruck/cat-facts](https://github.com/alexwohlbruck/cat-facts)
#
# ### Explanation
# `AssistantUtility.Create` acts based on the contents of a folder structure following a convention laid out in these notebooks. In this case, it copied the contents of instructions.md into the assistant manifest.json. It also parsed the cat-facts swagger which follows an Open API schema into tool defintions for the assistant.

# %%
var assistantId = await AssistantUtility.Create("Cat Facts", config);
var assistantId2 = await AssistantUtility.Create("ConversationUserProxy", config);
Console.WriteLine(assistantId);
Console.WriteLine(assistantId2);
# Out:
# asst_FgHAq0tNOAqmRg6oXZQeThwz

# %% [markdown]
# ## Run the Assistant
#
# `output.Dialog` shows the conversation. This version of AntRunner uses a built-in assistant definition. Upon completion the thread is deleted.

# %%
var assistantRunOptions = new AssistantRunOptions() {
    AssistantName = "Cat Facts",
    Instructions = "Create a plan to tell me something about cats. Review with me before using any tools",
    Evaluator = "ConversationUserProxy"
};
var output = await AntRunnerLib.AssistantRunner.RunThread(assistantRunOptions, config);
output.Dialog.DisplayAs("text/markdown");
# Out:
# User: Create a plan to tell me something about cats. Review with me before using any tools
#
# Assistant: Here's a plan to gather and share some interesting facts about cats with you:
#
# 1. **Identify the Source of Information**: Use a reliable source to fetch cat facts. In this case, we'll use a tool specifically designed to retrieve facts about cats.
#
# 2. **Gather the Information**: Execute the tool to gather the latest and most interesting cat facts.
#
# 3. **Review and Summarize**: Review the facts obtained and summarize them in a concise and engaging manner.
#
# 4. **Share with You**: Present the summarized information.
#
# 5. **Answer Any Additional Questions**: Be ready to delve into more details or answer any further questions you may have about cats.
#
# Let me know if this plan works for you or if there's anything else you'd like to adjust before we proceed!
#
# User: Yes, go ahead.
#
# Assistant: I called the tool named GetCatFacts with these arguments:
# ```
# {}
# ```
# and got this result:
# ```
# [{"status":{"verified":true,"sentCount":1},"_id":"58e00b5f0aac31001185ed24","user":"58e007480aac31001185ecef","text":"When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied \"cats.\"","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-02-19T21:20:03.434Z","deleted":false,"used":false},{"status":{"verified":true,"feedback":"","sentCount":1},"_id":"5887e1d85c873e0011036889","user":"5a9ac18c7478810ea6c06381","text":"Cats make about 100 different sounds. Dogs make only about 10.","__v":0,"source":"user","updatedAt":"2020-09-03T16:39:39.578Z","type":"cat","createdAt":"2018-01-15T21:20:00.003Z","deleted":false,"used":true},{"status":{"verified":true,"sentCount":1},"_id":"58e008780aac31001185ed05","user":"58e007480aac31001185ecef","text":"Owning a cat can reduce the risk of stroke and heart attack by a third.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-03-29T20:20:03.844Z","deleted":false,"used":false},{"status":{"verified":true,"sentCount":1},"_id":"58e009390aac31001185ed10","user":"58e007480aac31001185ecef","text":"Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-03-04T21:20:02.979Z","deleted":false,"used":false},{"status":{"verified":true,"sentCount":1},"_id":"58e00af60aac31001185ed1d","user":"58e007480aac31001185ecef","text":"It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.","__v":0,"source":"user","updatedAt":"2020-09-16T20:20:04.164Z","type":"cat","createdAt":"2018-01-15T21:20:02.945Z","deleted":false,"used":true}]
# ```
#
# Here are some fascinating facts about cats:
#
# 1. **Historical Tidbit**: Mary Todd Lincoln, wife of President Abraham Lincoln, reportedly responded with just one word when asked if her husband had any hobbies: "cats."
#
# 2. **Vocal Variety**: Cats can produce about 100 different sounds, whereas dogs make only about 10. This diversity in vocalization is part of what makes cats such intriguing communicators.
#
# 3. **Health Benefits**: Owning a cat can be beneficial for your health. It is said to reduce the risk of stroke and heart attack by a third, likely due to the calming presence and companionship they provide.
#
# 4. **Dietary Note**: Despite popular belief, most cats are lactose intolerant. Consuming milk can lead to stomach cramps and diarrhea. It's best to stick to providing them with clean, cool drinking water.
#
# 5. **Ancient Practices**: In ancient Egypt, it was illegal to kill cats. This was largely because they played a crucial role in controlling the rat population, which was vital for protecting food supplies.
#
# If you have any questions or want to know more about a specific fact, feel free to ask!

# %%
using OpenAI.ObjectModels.RequestModels;
//var threadId = "thread_UOO7mlBdewyWR238hJHCU2EC";
var threadId = "thread_GorH2lfVmccDIjX7nwMtlUPH";
var thread = await client.ThreadRetrieve(threadId);
var messages = (await client.ListMessages(threadId, new PaginationRequest { Order = "asc" })).Data;
var threadRuns = (await client.ListRuns(threadId, new PaginationRequest { Order = "asc" })).Data;

//Console.WriteLine("thread` -------------------------");
//Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(thread, new JsonSerializerOptions { WriteIndented = true }));
//Console.WriteLine("messages -------------------------");
//Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(messages, new JsonSerializerOptions { WriteIndented = true }));
//Console.WriteLine("threadRuns -------------------------");
//Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(threadRuns, new JsonSerializerOptions { WriteIndented = true }));

foreach(var message in messages)
{
    Console.WriteLine(message.RunId ?? "Root");
    Console.WriteLine(message.Role);
    Console.WriteLine(message.Content[0].Text.Value);
}
# Out:
# Root
# assistant
# All assistant context values are set. Do NOT use the `set-user-context-options` tool unless you need to update these values.
# Root
# user
# explain this code
#
# ```
# using AntRunnerLib;
# using Microsoft.EntityFrameworkCore;
# using static AntRunnerLib.ClientUtility;
# using System.Text.Json;
# using TranscriptProcessorLib.Diarized;
#
# namespace TranscriptProcessorLib.Activities
# {
#     public class OrchestrationState
#     {
#         public OrchestrationState() { }
#
#         public List<Transcript>? Transcripts { get; set; }
#
#     }
#
#     public class Orchestrator
#     {
#         public async Task Run()
#         {
#             var state = new OrchestrationState();
#             state.Transcripts = await IngestFiles.ProcessJsonFilesAsync(@"D:\Cyclotron\repos\Sentiment\TestFiles\Output");
#
#             int speakerCount = 0;
#
#             foreach (var transcript in state.Transcripts)
#             {
#                 var transcriptJson = JsonSerializer.Deserialize<DiarizedTranscript>(transcript.TranscriptJson) ?? throw new Exception("Error deserializing Json");
#                 var speakers = transcriptJson.GetSpeakers();
#                 speakerCount += speakers?.Count ?? 0;
#                 var output = await GetSpeakerNames.Run(transcript.Id.ToString());
#             }
#
#             using (var db = ApplicationDbContext.Factory())
#             {
#                 var recordCount = (await db.Speaker.ToListAsync()).Count;
#                 Console.WriteLine("recordCount: " + recordCount);
#             }
#
#             Console.WriteLine("speakerCount: " + speakerCount);
#
#             var config = AzureOpenAiConfigFactory.Get();
#             var client = GetOpenAiClient(config);
#             var assistantName = "SpeakerNameIdentifier";
#
#             if ((await client.AssistantList())?.Data?.FirstOrDefault(o => o.Name == assistantName) == null)
#             {
#                 await AssistantUtility.Create(assistantName, config);
#             }
#
#             assistantName = "SpeakerInsightsExtractor";
#
#             if ((await client.AssistantList())?.Data?.FirstOrDefault(o => o.Name == assistantName) == null)
#             {
#                 await AssistantUtility.Create(assistantName, config);
#             }
#
#             using (var db = ApplicationDbContext.Factory())
#             {
#                 var transcripts = await db.Transcript.ToListAsync();
#                 var speakersInDb = new List<Speaker>();
#                 foreach (var transcript in transcripts)
#                 {
#                     var transcriptJson = JsonSerializer.Deserialize<DiarizedTranscript>(transcript.TranscriptJson) ?? throw new Exception("Error deserializing Json");
#                     var transcriptText = transcriptJson.ToString();
#                     speakersInDb = await db.Speaker.Where(e => e.TranscriptId == transcript.Id).ToListAsync();
#                     var speakersInJson = transcriptJson.GetSpeakers();
#                     foreach (var dbSpeaker in speakersInDb)
#                     {
#                         var jsonSpeaker = speakersInJson.FirstOrDefault(s => $"[{dbSpeaker.DiarizedName}]" == s.SpeakerName);
#                         dbSpeaker.TotalDuration = jsonSpeaker?.TotalDuration ?? 0;
#
#                         foreach (var phrase in jsonSpeaker?.Dialogs ?? [])
#                         {
#                             if (await db.SpeakerPhrase.FirstOrDefaultAsync(e => e.SpeakerId == dbSpeaker.Id && e.Phrase == phrase) == null)
#                             {
#                                 await db.SpeakerPhrase.AddAsync(new SpeakerPhrase()
#                                 {
#                                     Phrase = phrase,
#                                     SpeakerId = dbSpeaker.Id
#                                 });
#                             }
#                         }
#                     }
#                     await db.SaveChangesAsync();
#
#                     speakersInDb = await db.Speaker.Include(s => s.Phrases).Where(e => e.TranscriptId == transcript.Id).ToListAsync();
#                     foreach (var dbSpeaker in speakersInDb)
#                     {
#                         foreach (var phrase in dbSpeaker.Phrases ?? new List<SpeakerPhrase>())
#                         {
#                             var dialog = DiarizedTranscript.GetAdjacentSpeakersAndDialogs(transcriptText, $"[{dbSpeaker.DiarizedName}]", phrase.Phrase ?? "");
#
#                             string input = $"speakerPhraseId: {phrase.Id}\n";
#                             input += $"speakerOfInterest: [{dbSpeaker.DiarizedName}]\n\n---\n{dialog}";
#
#                             var assistantRunOptions = new AssistantRunOptions()
#                             {
#                                 AssistantName = assistantName,
#                                 Instructions = input
#                             };
#
#                             var response = await AssistantRunner.RunThread(assistantRunOptions, config) ?? new();
#
#                             Console.WriteLine(input);
#                             Console.WriteLine("****************************************");
#                             Console.WriteLine( response.LastMessage);
#                             Console.WriteLine("########################################");
#                         }
#                     }
#                 }
#                 //Console.WriteLine("recordCount: " + recordCount);
#             }
#
#             Console.WriteLine("Done!");
#         }
#     }
# }
# ```
#
# and use graphviz to visualize the process
# run_IqlB0XNzHTZ7hVcZt7MJIqCw
# assistant
# Let's break down the code step-by-step to understand its functionality. The code seems to be part of a C# program that processes transcripts and interacts with a database and an AI assistant. Here's an overview:
#
# ### Code Breakdown
#
# 1. **Namespaces and Libraries**:
#    - The code uses several namespaces, including `AntRunnerLib`, `Microsoft.EntityFrameworkCore`, and `TranscriptProcessorLib.Diarized`. These likely contain classes and methods for file processing, database access, and transcript handling.
#
# 2. **Classes**:
#    - **OrchestrationState**: Holds the state of the orchestration, including a list of transcripts.
#    - **Orchestrator**: Contains the main logic for processing the transcripts.
#
# 3. **Run Method**:
#    - This is the main method in the `Orchestrator` class that orchestrates the entire process:
#      - **Ingest Files**: It calls `IngestFiles.ProcessJsonFilesAsync()` to read JSON files containing transcripts from a specified directory.
#      - **Speaker Count**: It loops through each transcript, deserializes it into a `DiarizedTranscript` object, counts the speakers, and retrieves their names.
#      - **Database Operations**:
#        - It connects to a database using `ApplicationDbContext`.
#        - It retrieves the count of speakers from the database and prints it.
#      - **Assistant Creation**: It checks if specific AI assistants exist and creates them if they don't.
#      - **Transcript Processing**: It retrieves all transcripts from the database, processes each one, and updates speaker details and phrases.
#      - **Assistant Interaction**: For each phrase spoken by a speaker, it interacts with an AI assistant, providing the context and printing the responses.
#
# 4. **Error Handling**: There are checks for null values when deserializing JSON data and when querying the database, ensuring that the program can handle unexpected data gracefully.
#
# ### Visualization with Graphviz
#
# Now, we will create a flow diagram using Graphviz to visualize the process outlined in the code. The diagram will represent the main steps involved in the `Run` method of the `Orchestrator` class.
#
# Let's create that visualization.
# run_IqlB0XNzHTZ7hVcZt7MJIqCw
# assistant
# We have created a flowchart representing the process in the `Run` method of the `Orchestrator` class. The flowchart illustrates the key steps involved, from starting the process to interacting with the AI assistant and completing the operation.
#
# You can download the flowchart image using the following link:
#
# [Download Transcript Processing Orchestrator Flowchart](sandbox:/mnt/data/transcript_processing_orchestrator.png)
#
# If you have any further questions or need additional explanations, feel free to ask!
# Root
# user
# Consider this additional code:
#
# ```
#     public class GetSpeakerNames
#     {
#         public async static Task<string> Run(string transcriptId)
#         {
#             var config = AzureOpenAiConfigFactory.Get();
#             var client = GetOpenAiClient(config);
#             var assistantName = "SpeakerNameIdentifier";
#
#             var assistantRunOptions = new AssistantRunOptions()
#             {
#                 AssistantName = assistantName,
#                 Instructions = $"TranscriptId: {transcriptId}",
#                 Evaluator = "SpeakerNameIdentifierEvaluator"
#             };
#             var response = await AssistantRunner.RunThread(assistantRunOptions, config) ?? new();
#             return response.LastMessage;
#         }
#     }
# }
# ```
#
# describe how the orchestration works with regards to invocations of RunThread and in terms of the named assistants
# run_ciRpBCLTR69VGQqhWQvInMP8
# assistant
# The additional code defines a class called `GetSpeakerNames`, which contains a method named `Run`. This method is responsible for invoking an AI assistant (specifically, the "SpeakerNameIdentifier") to retrieve speaker names based on a given transcript ID. Let's break down how this fits into the orchestration and how it interacts with the previous code.
#
# ### Explanation of `GetSpeakerNames.Run`
#
# 1. **Purpose**: The `Run` method in the `GetSpeakerNames` class is designed to interact with an AI assistant to identify speaker names from a transcript based on the provided `transcriptId`.
#
# 2. **Configuration**: It retrieves the configuration for the Azure OpenAI client using `AzureOpenAiConfigFactory.Get()`. This configuration is necessary to establish a connection to the AI service.
#
# 3. **Assistant Invocation**:
#    - The method creates an instance of `AssistantRunOptions`, which specifies:
#      - `AssistantName`: The name of the assistant to be invoked, which is "SpeakerNameIdentifier" in this case.
#      - `Instructions`: It sends the `transcriptId` as part of the instructions to the assistant, providing context for the task.
#      - `Evaluator`: Specifies the evaluator to use, which can be a mechanism to assess the quality of the assistant's output.
#
# 4. **RunThread Call**:
#    - The method calls `AssistantRunner.RunThread`, passing in the `assistantRunOptions` and the configuration. This method handles the interaction with the AI assistant, sending the request and waiting for a response.
#    - The result of the invocation is returned, specifically the `LastMessage` from the assistant's response, which presumably contains the names of the speakers identified from the transcript.
#
# ### Interaction with Orchestrator
#
# In the context of the `Orchestrator` class and its `Run` method:
#
# 1. **Loop Through Transcripts**:
#    - As the `Orchestrator` processes each transcript, it calls `GetSpeakerNames.Run(transcript.Id.ToString())` for each transcript. This invocation is where the orchestration delegates the task of retrieving speaker names to the `GetSpeakerNames` class.
#
# 2. **Named Assistants**:
#    - The orchestration relies on named assistants to perform specific tasks:
#      - **SpeakerNameIdentifier**: This assistant is invoked to identify and return the names of speakers in a given transcript. Each time a transcript is processed, this assistant is called, ensuring that the orchestration has the necessary speaker data.
#      - **SpeakerInsightsExtractor**: This assistant is also mentioned in the orchestration code. While the specific interaction with this assistant is not detailed in the additional code, it is likely intended for another aspect of processing, such as extracting insights or analysis related to the speakers or the transcript content.
#
# 3. **Flow of Control**:
#    - The orchestration first processes the transcripts, counts the speakers, and retrieves their names through the `GetSpeakerNames` class. This modular approach allows the orchestration logic to remain clean and focused while delegating specific tasks to dedicated classes and methods.
#
# ### Summary
#
# In summary, the orchestration works by invoking the `RunThread` method from the `GetSpeakerNames` class to interact with the "SpeakerNameIdentifier" AI assistant, enabling it to retrieve speaker names based on the context provided through `transcriptId`. The use of named assistants like "SpeakerNameIdentifier" and "SpeakerInsightsExtractor" allows for clear separation of responsibilities, making the system modular and easier to maintain. Each assistant serves a specific purpose, contributing to the overall functionality of the transcript processing workflow.
# Root
# user
# I refactored the orchestration:
#
# ```
# using AntRunnerLib;
# using Microsoft.EntityFrameworkCore;
# using static AntRunnerLib.ClientUtility;
# using System.Text.Json;
# using TranscriptProcessorLib.Diarized;
# using OpenAI.Managers;
#
# namespace TranscriptProcessorLib.Activities
# {
#     public class OrchestrationState
#     {
#         public OrchestrationState() { }
#
#         public List<Transcript>? Transcripts { get; set; }
#
#     }
#
#     public class Orchestrator
#     {
#         public async Task Run()
#         {
#             var state = new OrchestrationState();
#
#             var config = AzureOpenAiConfigFactory.Get();
#             var client = GetOpenAiClient(config);
#             await EnsureAssistantExists(config, client, "SpeakerNameIdentifier");
#             await EnsureAssistantExists(config, client, "SpeakerInsightsExtractor");
#
#             state.Transcripts = await IngestFiles.ProcessJsonFilesAsync(@"D:\Cyclotron\repos\Sentiment\TestFiles\Output");
#
#             int speakerCount = 0;
#
#             foreach (var transcript in state.Transcripts)
#             {
#                 var transcriptJson = JsonSerializer.Deserialize<DiarizedTranscript>(transcript.TranscriptJson) ?? throw new Exception("Error deserializing Json");
#                 var speakers = transcriptJson.GetSpeakers();
#                 speakerCount += speakers?.Count ?? 0;
#                 var output = await GetSpeakerNames.Run(transcript.Id.ToString());
#             }
#
#             using (var db = ApplicationDbContext.Factory())
#             {
#                 var recordCount = (await db.Speaker.ToListAsync()).Count;
#                 Console.WriteLine("recordCount: " + recordCount);
#             }
#
#             Console.WriteLine("speakerCount: " + speakerCount);
#
#             using (var db = ApplicationDbContext.Factory())
#             {
#                 var transcripts = await db.Transcript.ToListAsync();
#                 var speakersInDb = new List<Speaker>();
#                 foreach (var transcript in transcripts)
#                 {
#                     var transcriptJson = JsonSerializer.Deserialize<DiarizedTranscript>(transcript.TranscriptJson) ?? throw new Exception("Error deserializing Json");
#                     var transcriptText = transcriptJson.ToString();
#                     speakersInDb = await db.Speaker.Where(e => e.TranscriptId == transcript.Id).ToListAsync();
#                     var speakersInJson = transcriptJson.GetSpeakers();
#                     foreach (var dbSpeaker in speakersInDb)
#                     {
#                         var jsonSpeaker = speakersInJson.FirstOrDefault(s => $"[{dbSpeaker.DiarizedName}]" == s.SpeakerName);
#                         dbSpeaker.TotalDuration = jsonSpeaker?.TotalDuration ?? 0;
#
#                         foreach (var phrase in jsonSpeaker?.Dialogs ?? [])
#                         {
#                             if (await db.SpeakerPhrase.FirstOrDefaultAsync(e => e.SpeakerId == dbSpeaker.Id && e.Phrase == phrase) == null)
#                             {
#                                 await db.SpeakerPhrase.AddAsync(new SpeakerPhrase()
#                                 {
#                                     Phrase = phrase,
#                                     SpeakerId = dbSpeaker.Id
#                                 });
#                             }
#                         }
#                     }
#                     await db.SaveChangesAsync();
#
#                     speakersInDb = await db.Speaker.Include(s => s.Phrases).Where(e => e.TranscriptId == transcript.Id).ToListAsync();
#                     foreach (var dbSpeaker in speakersInDb)
#                     {
#                         foreach (var phrase in dbSpeaker.Phrases ?? new List<SpeakerPhrase>())
#                         {
#                             var dialog = DiarizedTranscript.GetAdjacentSpeakersAndDialogs(transcriptText, $"[{dbSpeaker.DiarizedName}]", phrase.Phrase ?? "");
#
#                             string input = $"speakerPhraseId: {phrase.Id}\n";
#                             input += $"speakerOfInterest: [{dbSpeaker.DiarizedName}]\n\n---\n{dialog}";
#
#                             var assistantRunOptions = new AssistantRunOptions()
#                             {
#                                 AssistantName = "SpeakerInsightsExtractor",
#                                 Instructions = input
#                             };
#
#                             var response = await AssistantRunner.RunThread(assistantRunOptions, config) ?? new();
#
#                             Console.WriteLine(input);
#                             Console.WriteLine("****************************************");
#                             Console.WriteLine(response.LastMessage);
#                             Console.WriteLine("########################################");
#                         }
#                     }
#                 }
#                 //Console.WriteLine("recordCount: " + recordCount);
#             }
#
#             Console.WriteLine("Done!");
#         }
#
#         private static async Task EnsureAssistantExists(AzureOpenAiConfig config, OpenAiService client, string assistantName)
#         {
#             if ((await client.AssistantList())?.Data?.FirstOrDefault(o => o.Name == assistantName) == null)
#             {
#                 await AssistantUtility.Create(assistantName, config);
#             }
#         }
#     }
# }
# ```
#
# update the description to match the changes related to the ensuring the assistants
# run_Tdy9TbYRaLzFNbhKgijAKdSu
# assistant
# The refactored code introduces a new method, `EnsureAssistantExists`, to streamline the process of checking for the existence of the named AI assistants before proceeding with the orchestration. Here's an updated description reflecting these changes:
#
# ### Updated Description of the Orchestration Process
#
# The refactored `Orchestrator` class is responsible for orchestrating the entire transcript processing workflow. It performs several key functions, including ensuring that specific AI assistants exist, ingesting transcript files, processing the transcripts, and interacting with the AI assistants to gather information and insights. The primary changes involve the encapsulation of the assistant existence check into a dedicated method, improving code clarity and maintainability.
#
# ### Key Changes and Workflow:
#
# 1. **Assistant Configuration**:
#    - The orchestration begins by retrieving the Azure OpenAI configuration and creating an OpenAI client instance using `AzureOpenAiConfigFactory.Get()` and `GetOpenAiClient(config)`.
#
# 2. **Ensuring Assistants Exist**:
#    - The method `EnsureAssistantExists` is invoked for each of the two assistants:
#      - **SpeakerNameIdentifier**: This assistant is responsible for identifying speaker names from transcripts.
#      - **SpeakerInsightsExtractor**: This assistant is intended for extracting insights related to speakers and their dialogues.
#    - The `EnsureAssistantExists` method checks if the assistant already exists by querying the assistant list from the OpenAI service. If the assistant does not exist, it creates it using `AssistantUtility.Create`.
#
# 3. **Ingesting Transcripts**:
#    - The orchestration then processes JSON files containing transcripts from the specified directory using `IngestFiles.ProcessJsonFilesAsync()`, storing the results in the `Transcripts` property of the `OrchestrationState`.
#
# 4. **Speaker Count**:
#    - For each transcript, the code deserializes the JSON data into a `DiarizedTranscript` object, counts the number of speakers, and invokes `GetSpeakerNames.Run(transcript.Id.ToString())` to retrieve the names of the speakers.
#
# 5. **Database Operations**:
#    - The orchestration connects to a database using `ApplicationDbContext`, retrieves the count of speakers, and prints it.
#    - It processes each transcript by updating speaker details and phrases in the database, ensuring that all relevant information is captured.
#
# 6. **Interacting with AI Assistants**:
#    - For each phrase spoken by a speaker, the orchestration constructs a context-sensitive input string and interacts with the **SpeakerInsightsExtractor** assistant using `AssistantRunner.RunThread`.
#    - The responses from the assistant are printed to the console, providing insights based on the dialogues and speaker context.
#
# 7. **Completion**:
#    - Finally, the orchestration prints "Done!" to indicate that all processing has been completed.
#
# ### Summary
#
# The refactoring enhances the clarity and organization of the orchestration process by encapsulating the assistant existence checks into a dedicated method, `EnsureAssistantExists`. This promotes better maintainability and readability while ensuring that the necessary AI assistants are available before the main processing begins. The orchestration effectively manages the workflow by coordinating file ingestion, speaker identification, database updates, and AI interactions, resulting in a streamlined transcript processing solution.
# Root
# user
# what about GetSpeakerNames? This is important
# run_k6KRK5h62eN5Iz8OCIu9rlSE
# assistant
# You're absolutely right! Let's update the description to include the role of the `GetSpeakerNames` class in the refactored orchestration process, emphasizing its importance in retrieving speaker information. Here’s the revised description:
#
# ### Updated Description of the Orchestration Process (Including `GetSpeakerNames`)
#
# The refactored `Orchestrator` class orchestrates the entire transcript processing workflow, which includes ensuring the existence of specific AI assistants, ingesting transcript files, processing the transcripts, and interacting with the AI assistants to gather information and insights. The `GetSpeakerNames` class plays a crucial role in this process by retrieving speaker names from the AI assistant based on the transcript ID.
#
# ### Key Components and Workflow:
#
# 1. **Assistant Configuration**:
#    - The orchestration begins by retrieving the Azure OpenAI configuration and creating an OpenAI client instance using `AzureOpenAiConfigFactory.Get()` and `GetOpenAiClient(config)`.
#
# 2. **Ensuring Assistants Exist**:
#    - The `EnsureAssistantExists` method is invoked for both assistants:
#      - **SpeakerNameIdentifier**: Responsible for identifying speaker names from transcripts.
#      - **SpeakerInsightsExtractor**: Intended for extracting insights related to speakers and their dialogues.
#    - This method checks for the existence of each assistant and creates it if it does not already exist.
#
# 3. **Ingesting Transcripts**:
#    - The orchestration processes JSON files containing transcripts from a specified directory using `IngestFiles.ProcessJsonFilesAsync()`, storing the results in the `Transcripts` property of the `OrchestrationState`.
#
# 4. **Speaker Count**:
#    - For each transcript, the code deserializes the JSON data into a `DiarizedTranscript` object, counts the number of speakers, and invokes `GetSpeakerNames.Run(transcript.Id.ToString())`.
#      - **GetSpeakerNames**: This static method interacts with the "SpeakerNameIdentifier" AI assistant to retrieve the names of the speakers associated with the transcript ID. It encapsulates the logic for making this call, ensuring that the orchestration remains clean and focused on workflow management.
#
# 5. **Database Operations**:
#    - The orchestration connects to a database using `ApplicationDbContext`, retrieves the count of speakers, and prints it.
#    - It processes each transcript, updating speaker details and phrases in the database to ensure that all relevant information is captured.
#
# 6. **Interacting with AI Assistants**:
#    - For each phrase spoken by a speaker, the orchestration constructs a context-sensitive input string and interacts with the **SpeakerInsightsExtractor** assistant using `AssistantRunner.RunThread`.
#    - The responses from the assistant are printed to the console, providing insights based on the dialogues and speaker context.
#
# 7. **Completion**:
#    - Finally, the orchestration prints "Done!" to indicate that all processing has been completed.
#
# ### Summary
#
# In this refactored orchestration, the `GetSpeakerNames` class is integral to efficiently retrieving speaker names from the AI assistant. By encapsulating the assistant interaction within this class, the orchestration maintains clarity and separation of concerns, allowing each component to focus on its specific responsibility. The entire workflow—from configuring assistants, ingesting transcripts, and retrieving speaker data, to updating the database and interacting with AI—works cohesively to provide a streamlined transcript processing solution.
# Root
# user
# from this, create a dataflow diagram of steps 3-6
# run_rFHHxmYKoQ1A1DnW43C6mkdO
# assistant
# To create a data flow diagram (DFD) for steps 3 to 6 of the orchestration process, we'll represent the flow of data between different components, such as the ingestion of transcripts, the retrieval of speaker names, database operations, and interactions with the AI assistants.
#
# ### Steps to Represent in the Data Flow Diagram:
#
# 1. **Ingest Transcripts** (Step 3)
#    - Input: JSON files from a directory.
#    - Output: List of transcripts stored in `OrchestrationState`.
#
# 2. **Count Speakers and Retrieve Names** (Step 4)
#    - Input: List of transcripts.
#    - Process: Deserialization of JSON and invocation of `GetSpeakerNames.Run()`.
#    - Output: Speaker names retrieved from the "SpeakerNameIdentifier" assistant.
#
# 3. **Database Operations** (Step 5)
#    - Input: Speaker names and transcript data.
#    - Process: Database interaction to update speaker details and phrases.
#    - Output: Updated speaker records in the database.
#
# 4. **Interact with AI Assistants** (Step 6)
#    - Input: Speaker phrases and context for each speaker.
#    - Process: Invocation of `AssistantRunner.RunThread()` with the "SpeakerInsightsExtractor" assistant.
#    - Output: Insights and responses from the AI assistant.
#
# ### Data Flow Diagram Creation
#
# Let's visualize these steps in a data flow diagram format.
# run_rFHHxmYKoQ1A1DnW43C6mkdO
# assistant
# We have created a data flow diagram (DFD) that visually represents steps 3 to 6 of the orchestration process. The diagram illustrates the flow of data between different components involved in the ingestion of transcripts, retrieval of speaker names, database operations, and interactions with the AI assistants.
#
# You can download the data flow diagram image using the following link:
#
# [Download Transcript Processing Data Flow Diagram](sandbox:/mnt/data/transcript_processing_dataflow.png)
#
# ### Diagram Overview:
# - **Ingestion**: JSON files are ingested and transformed into an orchestration state containing transcripts.
# - **Deserialization**: The transcripts are deserialized into `DiarizedTranscript` objects.
# - **Speaker Name Retrieval**: The `GetSpeakerNames` method is invoked to retrieve speaker names from the AI assistant.
# - **Database Update**: The database is updated with speaker details, and speaker phrases are prepared for interaction with the AI.
# - **AI Interaction**: Speaker phrases are sent to the "SpeakerInsightsExtractor" AI assistant, and insights are generated as responses.
#
# If you have any further questions or need additional modifications, feel free to ask!
# Root
# user
# you can display the image here, please do
# run_HOftXMYCm1cXfAvjU3MAbAmL
# assistant
# System.NullReferenceException: Object reference not set to an instance of an object.
#
#    at Submission#36.<<Initialize>>d__0.MoveNext()
#
# --- End of stack trace from previous location ---
#
#    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

# %%
Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(threadRuns, new JsonSerializerOptions { WriteIndented = true }));
# Out:
# [
#   {
#     "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#     "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#     "status": "completed",
#     "required_action": null,
#     "last_error": null,
#     "incomplete_details": null,
#     "expires_at": null,
#     "started_at": 1735875616,
#     "cancelled_at": null,
#     "failed_at": null,
#     "completed_at": 1735875617,
#     "instructions": "You are the Mail Ants of the Ant Army. You help people work use email\r\n\r\nAlways ask for feedback and review content with the user before sending or replying to messages\r\n\r\nNever start new conversations or reply to messages automatically. Doing so is a grave offense and serious error. Wait for specific confirmation **before** proceeding.\r\n\r\n## Current User information\r\nUse the user.name and user.email context options for information about the user. If these values are not set, call the GetUser action and then use the \u0027set-user-context-options\u0027 tool. **Set the user.name and user.email context options before doing anything else**.\r\n\r\n## Current Date\r\nIf you need to filter by dates relative to the current day, use the system.currentDate context option.\r\n\r\n## Signatures\r\nUse the outlook.signature context option when drafting emails. If this value is not set when writing an email, ask the user what they would like their signature to be then set outlook.signature using the \u0027set-user-context-options\u0027 tool. **Do not start or reply to a conversation if outlook.signature has not been set**.\r\n\r\n## Finding Messages from People\r\nUse \u0060$filter\u0060 for **Partial Name or Address Search in Sender** and follow **Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060**: the fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n## Sending Messages to People\r\nWhen asked to send an email, if the recipient\u0027s address is not known, try to find it in using Partial Name Search in Sender instructions\r\n\r\n## Always Confirm Message Content\r\nNever send a message without confirming the subject and body content with the user\r\n\r\n## Include links to emails using webLink\r\n\r\n## Filters\r\nFirst find a list of messages of interest using a $filter and then drill into individual messages with the id\u0027s found. Use permissive filters for emails and avoid -eq unless explicitly instructed to find exact matches\r\n\r\n### **Parameters**:\r\n#### \u0060$select\u0060: Choose specific fields to return in the response. \r\n**Always $select=receivedDateTime,from,subject,webLink,bodyPreview**\r\n\r\n#### \u0060$orderby\u0060: Sorts the results\r\nThe fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n#### \u0060$filter\u0060: Apply conditions to refine the result set\r\n**Text Filters**: Retrieve messages that contain a certain string within the subject: \u0060receivedDateTime gt 1900-01-01 and contains(subject,\u0027budget\u0027)\u0060.\r\n\r\n**Date Filters**: Get messages from a certain date range: \u0060receivedDateTime ge 2023-01-01 and receivedDateTime le 2023-01-31\u0060. Use eq to find a specific day: receivedDateTime eq 2024-07-04.\r\n\r\n**Sender Filters**: Filter messages based on the sender\u0027s address: \u0060receivedDateTime gt 1900-01-01 and sender/emailAddress/address eq \u0027example@domain.com\u0027\u0060\r\n\r\n**Partial Name or Address Search in Sender**: Filter by partial sender name or address: \u0060receivedDateTime gt 1900-01-01 and (contains(sender/emailAddress/name, \u0027bob\u0027) or contains(sender/emailAddress/address, \u0027deepak\u0027))\u0060\r\n\r\n### VITAL Instructions for correct \u0060$filter\u0060 and \u0060$orderby\u0060 Usage\r\n\r\n#### Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060:\r\n**Inclusion**: Every field you want to sort by using \u0060$orderby\u0060 must be included in your \u0060$filter\u0060 clause\r\n\r\n**Comparison**: Introduce a benign comparison in the \u0060$filter\u0060 for the \u0060$orderby\u0060 field, such as \u0060receivedDateTime gt 1900-01-01\u0060 to ensure the presence of the field without restricting results unnecessarily\r\n\r\n**Order**: The fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r ...
#     "tools": [
#       {
#         "type": "code_interpreter"
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "GetUser",
#           "description": "Get the user profile information",
#           "parameters": {
#             "type": "object",
#             "properties": {},
#             "required": []
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "FindMessages",
#           "description": "Get user messages with previews of the body",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "$top": {
#                 "type": "integer",
#                 "description": "Limits the number of messages returned in a single response.",
#                 "default": 10
#               },
#               "$filter": {
#                 "type": "string",
#                 "description": "Filters the messages based on specified conditions. MUST include receivedDateTime gt 1900-01-01 if using $orderby."
#               },
#               "$orderby": {
#                 "type": "string",
#                 "description": "Specifies the sort order. Every field in \u0060$orderby\u0060 MUST be included in \u0060$filter\u0060"
#               },
#               "$select": {
#                 "type": "string",
#                 "description": "id,receivedDateTime,from,subject,webLink,bodyPreview"
#               }
#             },
#             "required": [
#               "$top",
#               "$orderby",
#               "$select"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "GetMessageDetails",
#           "description": "Get the full body of a specific message",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "id": {
#                 "type": "string",
#                 "description": "The unique identifier of the message."
#               }
#             },
#             "required": [
#               "id"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "StartNewConvesation",
#           "description": "Start a new conversation by sending a message. Verify content with user before sending.",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "message": {
#                 "type": "object"
#               },
#               "saveToSentItems": {
#                 "type": "string",
#                 "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#                 "enum": [
#                   "true",
#                   "false"
#                 ]
#               }
#             },
#             "required": []
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "ReplyToMessage",
#           "description": "Reply to a message in an ongoing conversation. Verify content with user before sending.",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "id": {
#                 "type": "string",
#                 "description": "The unique identifier of the message to reply to."
#               },
#               "message": {
#                 "type": "object"
#               },
#               "saveToSentItems": {
#                 "type": "string",
#                 "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#                 "enum": [
#                   "true",
#                   "false"
#                 ]
#               }
#             },
#             "required": [
#               "id"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "set-user-context-options",
#           "description": "Set the user context options",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "userContextOptions": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "properties": {
#                     "key": {
#                       "type": "string"
#                     },
#                     "value": {
#                       "type": "string"
#                     }
#                   },
#                   "required": [
#                     "key",
#                     "value"
#                   ]
#                 }
#               }
#             },
#             "required": [
#               "userContextOptions"
#             ]
#           }
#         }
#       }
#     ],
#     "usage": {
#       "prompt_tokens": 4477,
#       "completion_tokens": 109,
#       "total_tokens": 4586
#     },
#     "temperature": 0.5,
#     "max_prompt_tokens": null,
#     "max_completion_tokens": null,
#     "truncation_strategy": {
#       "type": "auto",
#       "last_messages": null
#     },
#     "tool_choice": "auto",
#     "response_format": "auto",
#     "created_at": 1735875613,
#     "file_ids": null,
#     "id": "run_BfQeU55OZ8vaXxWvuzNd6Ajq",
#     "metadata": {},
#     "model": "gpt-4o-mini",
#     "StreamEvent": null,
#     "IsDelta": false,
#     "Successful": true,
#     "error": null,
#     "HttpStatusCode": 0,
#     "HeaderValues": null,
#     "object": "thread.run"
#   },
#   {
#     "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#     "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#     "status": "completed",
#     "required_action": null,
#     "last_error": null,
#     "incomplete_details": null,
#     "expires_at": null,
#     "started_at": 1735875681,
#     "cancelled_at": null,
#     "failed_at": null,
#     "completed_at": 1735875683,
#     "instructions": "You are the Mail Ants of the Ant Army. You help people work use email\r\n\r\nAlways ask for feedback and review content with the user before sending or replying to messages\r\n\r\nNever start new conversations or reply to messages automatically. Doing so is a grave offense and serious error. Wait for specific confirmation **before** proceeding.\r\n\r\n## Current User information\r\nUse the user.name and user.email context options for information about the user. If these values are not set, call the GetUser action and then use the \u0027set-user-context-options\u0027 tool. **Set the user.name and user.email context options before doing anything else**.\r\n\r\n## Current Date\r\nIf you need to filter by dates relative to the current day, use the system.currentDate context option.\r\n\r\n## Signatures\r\nUse the outlook.signature context option when drafting emails. If this value is not set when writing an email, ask the user what they would like their signature to be then set outlook.signature using the \u0027set-user-context-options\u0027 tool. **Do not start or reply to a conversation if outlook.signature has not been set**.\r\n\r\n## Finding Messages from People\r\nUse \u0060$filter\u0060 for **Partial Name or Address Search in Sender** and follow **Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060**: the fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n## Sending Messages to People\r\nWhen asked to send an email, if the recipient\u0027s address is not known, try to find it in using Partial Name Search in Sender instructions\r\n\r\n## Always Confirm Message Content\r\nNever send a message without confirming the subject and body content with the user\r\n\r\n## Include links to emails using webLink\r\n\r\n## Filters\r\nFirst find a list of messages of interest using a $filter and then drill into individual messages with the id\u0027s found. Use permissive filters for emails and avoid -eq unless explicitly instructed to find exact matches\r\n\r\n### **Parameters**:\r\n#### \u0060$select\u0060: Choose specific fields to return in the response. \r\n**Always $select=receivedDateTime,from,subject,webLink,bodyPreview**\r\n\r\n#### \u0060$orderby\u0060: Sorts the results\r\nThe fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n#### \u0060$filter\u0060: Apply conditions to refine the result set\r\n**Text Filters**: Retrieve messages that contain a certain string within the subject: \u0060receivedDateTime gt 1900-01-01 and contains(subject,\u0027budget\u0027)\u0060.\r\n\r\n**Date Filters**: Get messages from a certain date range: \u0060receivedDateTime ge 2023-01-01 and receivedDateTime le 2023-01-31\u0060. Use eq to find a specific day: receivedDateTime eq 2024-07-04.\r\n\r\n**Sender Filters**: Filter messages based on the sender\u0027s address: \u0060receivedDateTime gt 1900-01-01 and sender/emailAddress/address eq \u0027example@domain.com\u0027\u0060\r\n\r\n**Partial Name or Address Search in Sender**: Filter by partial sender name or address: \u0060receivedDateTime gt 1900-01-01 and (contains(sender/emailAddress/name, \u0027bob\u0027) or contains(sender/emailAddress/address, \u0027deepak\u0027))\u0060\r\n\r\n### VITAL Instructions for correct \u0060$filter\u0060 and \u0060$orderby\u0060 Usage\r\n\r\n#### Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060:\r\n**Inclusion**: Every field you want to sort by using \u0060$orderby\u0060 must be included in your \u0060$filter\u0060 clause\r\n\r\n**Comparison**: Introduce a benign comparison in the \u0060$filter\u0060 for the \u0060$orderby\u0060 field, such as \u0060receivedDateTime gt 1900-01-01\u0060 to ensure the presence of the field without restricting results unnecessarily\r\n\r\n**Order**: The fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r ...
#     "tools": [
#       {
#         "type": "code_interpreter"
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "GetUser",
#           "description": "Get the user profile information",
#           "parameters": {
#             "type": "object",
#             "properties": {},
#             "required": []
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "FindMessages",
#           "description": "Get user messages with previews of the body",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "$top": {
#                 "type": "integer",
#                 "description": "Limits the number of messages returned in a single response.",
#                 "default": 10
#               },
#               "$filter": {
#                 "type": "string",
#                 "description": "Filters the messages based on specified conditions. MUST include receivedDateTime gt 1900-01-01 if using $orderby."
#               },
#               "$orderby": {
#                 "type": "string",
#                 "description": "Specifies the sort order. Every field in \u0060$orderby\u0060 MUST be included in \u0060$filter\u0060"
#               },
#               "$select": {
#                 "type": "string",
#                 "description": "id,receivedDateTime,from,subject,webLink,bodyPreview"
#               }
#             },
#             "required": [
#               "$top",
#               "$orderby",
#               "$select"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "GetMessageDetails",
#           "description": "Get the full body of a specific message",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "id": {
#                 "type": "string",
#                 "description": "The unique identifier of the message."
#               }
#             },
#             "required": [
#               "id"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "StartNewConvesation",
#           "description": "Start a new conversation by sending a message. Verify content with user before sending.",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "message": {
#                 "type": "object"
#               },
#               "saveToSentItems": {
#                 "type": "string",
#                 "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#                 "enum": [
#                   "true",
#                   "false"
#                 ]
#               }
#             },
#             "required": []
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "ReplyToMessage",
#           "description": "Reply to a message in an ongoing conversation. Verify content with user before sending.",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "id": {
#                 "type": "string",
#                 "description": "The unique identifier of the message to reply to."
#               },
#               "message": {
#                 "type": "object"
#               },
#               "saveToSentItems": {
#                 "type": "string",
#                 "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#                 "enum": [
#                   "true",
#                   "false"
#                 ]
#               }
#             },
#             "required": [
#               "id"
#             ]
#           }
#         }
#       },
#       {
#         "type": "function",
#         "function": {
#           "name": "set-user-context-options",
#           "description": "Set the user context options",
#           "parameters": {
#             "type": "object",
#             "properties": {
#               "userContextOptions": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "properties": {
#                     "key": {
#                       "type": "string"
#                     },
#                     "value": {
#                       "type": "string"
#                     }
#                   },
#                   "required": [
#                     "key",
#                     "value"
#                   ]
#                 }
#               }
#             },
#             "required": [
#               "userContextOptions"
#             ]
#           }
#         }
#       }
#     ],
#     "usage": {
#       "prompt_tokens": 9580,
#       "completion_tokens": 159,
#       "total_tokens": 9739
#     },
#     "temperature": 0.5,
#     "max_prompt_tokens": null,
#     "max_completion_tokens": null,
#     "truncation_strategy": {
#       "type": "auto",
#       "last_messages": null
#     },
#     "tool_choice": "auto",
#     "response_format": "auto",
#     "created_at": 1735875678,
#     "file_ids": null,
#     "id": "run_LgItLL38Ml3ENBTaGj635VHm",
#     "metadata": {},
#     "model": "gpt-4o-mini",
#     "StreamEvent": null,
#     "IsDelta": false,
#     "Successful": true,
#     "error": null,
#     "HttpStatusCode": 0,
#     "HeaderValues": null,
#     "object": "thread.run"
#   },
#   {
#     "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#     "assistant_id": "asst_iEBWV9FPiVGc6qSrwTcHEbr2",
#     "status": "completed",
#     "required_action": null,
#     "last_error": null,
#     "incomplete_details": null,
#     "expires_at": null,
#     "started_at": 1735875825,
#     "cancelled_at": null,
#     "failed_at": null,
#     "completed_at": 1735875828,
#     "instructions": "You are the code ants and refer to yourself as \u0027we\u0027\n\nYou use python to do tasks for the user",
#     "tools": [
#       {
#         "type": "code_interpreter"
#       }
#     ],
#     "usage": {
#       "prompt_tokens": 5357,
#       "completion_tokens": 325,
#       "total_tokens": 5682
#     },
#     "temperature": 0.7,
#     "max_prompt_tokens": null,
#     "max_completion_tokens": null,
#     "truncation_strategy": {
#       "type": "auto",
#       "last_messages": null
#     },
#     "tool_choice": "auto",
#     "response_format": "auto",
#     "created_at": 1735875825,
#     "file_ids": null,
#     "id": "run_XGadmiCy8Vh84vx4iZm2ai8V",
#     "metadata": {},
#     "model": "gpt-4o-mini",
#     "StreamEvent": null,
#     "IsDelta": false,
#     "Successful": true,
#     "error": null,
#     "HttpStatusCode": 0,
#     "HeaderValues": null,
#     "object": "thread.run"
#   }
# ]

# %%
foreach(var run in threadRuns)
{
    var run2 = await client.RunRetrieve(threadId, run.Id);
    Console.WriteLine("Run `***********************");
    Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(run2, new JsonSerializerOptions { WriteIndented = true }));
    var runSteps = await client.RunStepsList(threadId, run.Id, new PaginationRequest { Order = "asc" });
    Console.WriteLine("Run Steps ***********************");
    Console.WriteLine(System.Text.Json.JsonSerializer.Serialize(runSteps, new JsonSerializerOptions { WriteIndented = true }));
    foreach(var step in runSteps.Data)
    {
        if(step.StepDetails.MessageCreation?.MessageId != null)
        {
            var message = await client.RetrieveMessage(threadId, step.StepDetails.MessageCreation?.MessageId);
            //Console.WriteLine("message +++++++++++++++++++++++");
            Console.WriteLine(message.Content[0].Text.Value);
        }
    }
}
# Out:
# Run `***********************
# {
#   "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#   "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#   "status": "completed",
#   "required_action": null,
#   "last_error": null,
#   "incomplete_details": null,
#   "expires_at": null,
#   "started_at": 1735875616,
#   "cancelled_at": null,
#   "failed_at": null,
#   "completed_at": 1735875617,
#   "instructions": "You are the Mail Ants of the Ant Army. You help people work use email\r\n\r\nAlways ask for feedback and review content with the user before sending or replying to messages\r\n\r\nNever start new conversations or reply to messages automatically. Doing so is a grave offense and serious error. Wait for specific confirmation **before** proceeding.\r\n\r\n## Current User information\r\nUse the user.name and user.email context options for information about the user. If these values are not set, call the GetUser action and then use the \u0027set-user-context-options\u0027 tool. **Set the user.name and user.email context options before doing anything else**.\r\n\r\n## Current Date\r\nIf you need to filter by dates relative to the current day, use the system.currentDate context option.\r\n\r\n## Signatures\r\nUse the outlook.signature context option when drafting emails. If this value is not set when writing an email, ask the user what they would like their signature to be then set outlook.signature using the \u0027set-user-context-options\u0027 tool. **Do not start or reply to a conversation if outlook.signature has not been set**.\r\n\r\n## Finding Messages from People\r\nUse \u0060$filter\u0060 for **Partial Name or Address Search in Sender** and follow **Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060**: the fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n## Sending Messages to People\r\nWhen asked to send an email, if the recipient\u0027s address is not known, try to find it in using Partial Name Search in Sender instructions\r\n\r\n## Always Confirm Message Content\r\nNever send a message without confirming the subject and body content with the user\r\n\r\n## Include links to emails using webLink\r\n\r\n## Filters\r\nFirst find a list of messages of interest using a $filter and then drill into individual messages with the id\u0027s found. Use permissive filters for emails and avoid -eq unless explicitly instructed to find exact matches\r\n\r\n### **Parameters**:\r\n#### \u0060$select\u0060: Choose specific fields to return in the response. \r\n**Always $select=receivedDateTime,from,subject,webLink,bodyPreview**\r\n\r\n#### \u0060$orderby\u0060: Sorts the results\r\nThe fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n#### \u0060$filter\u0060: Apply conditions to refine the result set\r\n**Text Filters**: Retrieve messages that contain a certain string within the subject: \u0060receivedDateTime gt 1900-01-01 and contains(subject,\u0027budget\u0027)\u0060.\r\n\r\n**Date Filters**: Get messages from a certain date range: \u0060receivedDateTime ge 2023-01-01 and receivedDateTime le 2023-01-31\u0060. Use eq to find a specific day: receivedDateTime eq 2024-07-04.\r\n\r\n**Sender Filters**: Filter messages based on the sender\u0027s address: \u0060receivedDateTime gt 1900-01-01 and sender/emailAddress/address eq \u0027example@domain.com\u0027\u0060\r\n\r\n**Partial Name or Address Search in Sender**: Filter by partial sender name or address: \u0060receivedDateTime gt 1900-01-01 and (contains(sender/emailAddress/name, \u0027bob\u0027) or contains(sender/emailAddress/address, \u0027deepak\u0027))\u0060\r\n\r\n### VITAL Instructions for correct \u0060$filter\u0060 and \u0060$orderby\u0060 Usage\r\n\r\n#### Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060:\r\n**Inclusion**: Every field you want to sort by using \u0060$orderby\u0060 must be included in your \u0060$filter\u0060 clause\r\n\r\n**Comparison**: Introduce a benign comparison in the \u0060$filter\u0060 for the \u0060$orderby\u0060 field, such as \u0060receivedDateTime gt 1900-01-01\u0060 to ensure the presence of the field without restricting results unnecessarily\r\n\r\n**Order**: The fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n ...
#   "tools": [
#     {
#       "type": "code_interpreter"
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "GetUser",
#         "description": "Get the user profile information",
#         "parameters": {
#           "type": "object",
#           "properties": {},
#           "required": []
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "FindMessages",
#         "description": "Get user messages with previews of the body",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "$top": {
#               "type": "integer",
#               "description": "Limits the number of messages returned in a single response.",
#               "default": 10
#             },
#             "$filter": {
#               "type": "string",
#               "description": "Filters the messages based on specified conditions. MUST include receivedDateTime gt 1900-01-01 if using $orderby."
#             },
#             "$orderby": {
#               "type": "string",
#               "description": "Specifies the sort order. Every field in \u0060$orderby\u0060 MUST be included in \u0060$filter\u0060"
#             },
#             "$select": {
#               "type": "string",
#               "description": "id,receivedDateTime,from,subject,webLink,bodyPreview"
#             }
#           },
#           "required": [
#             "$top",
#             "$orderby",
#             "$select"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "GetMessageDetails",
#         "description": "Get the full body of a specific message",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "id": {
#               "type": "string",
#               "description": "The unique identifier of the message."
#             }
#           },
#           "required": [
#             "id"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "StartNewConvesation",
#         "description": "Start a new conversation by sending a message. Verify content with user before sending.",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "message": {
#               "type": "object"
#             },
#             "saveToSentItems": {
#               "type": "string",
#               "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#               "enum": [
#                 "true",
#                 "false"
#               ]
#             }
#           },
#           "required": []
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "ReplyToMessage",
#         "description": "Reply to a message in an ongoing conversation. Verify content with user before sending.",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "id": {
#               "type": "string",
#               "description": "The unique identifier of the message to reply to."
#             },
#             "message": {
#               "type": "object"
#             },
#             "saveToSentItems": {
#               "type": "string",
#               "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#               "enum": [
#                 "true",
#                 "false"
#               ]
#             }
#           },
#           "required": [
#             "id"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "set-user-context-options",
#         "description": "Set the user context options",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "userContextOptions": {
#               "type": "array",
#               "items": {
#                 "type": "object",
#                 "properties": {
#                   "key": {
#                     "type": "string"
#                   },
#                   "value": {
#                     "type": "string"
#                   }
#                 },
#                 "required": [
#                   "key",
#                   "value"
#                 ]
#               }
#             }
#           },
#           "required": [
#             "userContextOptions"
#           ]
#         }
#       }
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 4477,
#     "completion_tokens": 109,
#     "total_tokens": 4586
#   },
#   "temperature": 0.5,
#   "max_prompt_tokens": null,
#   "max_completion_tokens": null,
#   "truncation_strategy": {
#     "type": "auto",
#     "last_messages": null
#   },
#   "tool_choice": "auto",
#   "response_format": "auto",
#   "created_at": 1735875613,
#   "file_ids": null,
#   "id": "run_BfQeU55OZ8vaXxWvuzNd6Ajq",
#   "metadata": {},
#   "model": "gpt-4o-mini",
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:10+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "fc187c73-6fdf-4620-893d-1856936c04dc",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "a375e401-769b-45f2-870c-5d4872d51622"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "fc187c73-6fdf-4620-893d-1856936c04dc"
#       ],
#       "openai-processing-ms": [
#         "99"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "42d81be9-1a0b-422e-b94f-378863325116"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:10 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "99",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "thread.run"
# }
# Run Steps ***********************
# {
#   "data": [
#     {
#       "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#       "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#       "run_id": "run_BfQeU55OZ8vaXxWvuzNd6Ajq",
#       "type": "tool_calls",
#       "status": "completed",
#       "step_details": {
#         "type": "tool_calls",
#         "tool_calls": [
#           {
#             "id": "call_2t1ikky8sGmnHnoXUvdqIKv3",
#             "type": "function",
#             "function": {
#               "name": "FindMessages",
#               "arguments": "{\u0022$top\u0022:3,\u0022$filter\u0022:\u0022receivedDateTime gt 1900-01-01\u0022,\u0022$orderby\u0022:\u0022receivedDateTime desc\u0022,\u0022$select\u0022:\u0022subject\u0022}",
#               "output": "{\u0022value\u0022:[{\u0022id\u0022:\u0022AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAAAAAEMAACbKv_XV2mrRagMoaMUBFn6AAZdHg59AAA=\u0022,\u0022subject\u0022:\u0022Re: [EXTERNAL] Azure Open AI from SPA apps without backends\u0022},{\u0022id\u0022:\u0022AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAAAAAEMAACbKv_XV2mrRagMoaMUBFn6AAZdHg58AAA=\u0022,\u0022subject\u0022:\u0022Re: [EXTERNAL] Azure Open AI from SPA apps without backends\u0022},{\u0022id\u0022:\u0022AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAA8to1eAACbKv_XV2mrRagMoaMUBFn6AAZdHkkYAAA=\u0022,\u0022subject\u0022:\u0022your business, now\u0027s your chance - SBA rates just got better!\u0022}],\u0022@odata.nextLink\u0022:\u0022https://graph.microsoft.com/v1.0/me/messages?%24filter=receivedDateTime\u002Bgt\u002B1900-01-01\u0026%24orderby=receivedDateTime\u002Bdesc\u0026%24select=subject\u0026%24top=3\u0026%24skip=3\u0022}"
#             }
#           }
#         ]
#       },
#       "last_error": null,
#       "expired_at": null,
#       "cancelled_at": null,
#       "failed_at": null,
#       "completed_at": 1735875615,
#       "metadata": null,
#       "usage": {
#         "prompt_tokens": 2004,
#         "completion_tokens": 44,
#         "total_tokens": 2048
#       },
#       "created_at": 1735875614,
#       "id": "step_bPhaNXvQMNnn58RpZwdm1htl",
#       "StreamEvent": null,
#       "IsDelta": false,
#       "Successful": true,
#       "error": null,
#       "HttpStatusCode": 0,
#       "HeaderValues": null,
#       "object": "thread.run.step"
#     },
#     {
#       "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#       "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#       "run_id": "run_BfQeU55OZ8vaXxWvuzNd6Ajq",
#       "type": "message_creation",
#       "status": "completed",
#       "step_details": {
#         "type": "message_creation",
#         "message_creation": {
#           "message_id": "msg_N6ZSX9FPwh4r7L4GGrJu5YIT"
#         },
#         "tool_calls": []
#       },
#       "last_error": null,
#       "expired_at": null,
#       "cancelled_at": null,
#       "failed_at": null,
#       "completed_at": 1735875617,
#       "metadata": null,
#       "usage": {
#         "prompt_tokens": 2473,
#         "completion_tokens": 65,
#         "total_tokens": 2538
#       },
#       "created_at": 1735875616,
#       "id": "step_mCiMkChUN6yHMlKi7sIx50PX",
#       "StreamEvent": null,
#       "IsDelta": false,
#       "Successful": true,
#       "error": null,
#       "HttpStatusCode": 0,
#       "HeaderValues": null,
#       "object": "thread.run.step"
#     }
#   ],
#   "first_id": "step_bPhaNXvQMNnn58RpZwdm1htl",
#   "last_id": "step_mCiMkChUN6yHMlKi7sIx50PX",
#   "has_more": false,
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:10+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "10a6ff99-e148-4978-b48f-3fc4e60dbd0b",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "5f38f812-4d40-4ded-a210-2c053092f2a9"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "10a6ff99-e148-4978-b48f-3fc4e60dbd0b"
#       ],
#       "openai-processing-ms": [
#         "143"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "6bb4637e-4114-46ab-9de4-1c50f1bdb1aa"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:10 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "143",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "list"
# }
# Here are the subjects of your three most recent emails:
#
# 1. Re: [EXTERNAL] Azure Open AI from SPA apps without backends
# 2. Re: [EXTERNAL] Azure Open AI from SPA apps without backends
# 3. your business, now's your chance - SBA rates just got better!
# Run `***********************
# {
#   "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#   "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#   "status": "completed",
#   "required_action": null,
#   "last_error": null,
#   "incomplete_details": null,
#   "expires_at": null,
#   "started_at": 1735875681,
#   "cancelled_at": null,
#   "failed_at": null,
#   "completed_at": 1735875683,
#   "instructions": "You are the Mail Ants of the Ant Army. You help people work use email\r\n\r\nAlways ask for feedback and review content with the user before sending or replying to messages\r\n\r\nNever start new conversations or reply to messages automatically. Doing so is a grave offense and serious error. Wait for specific confirmation **before** proceeding.\r\n\r\n## Current User information\r\nUse the user.name and user.email context options for information about the user. If these values are not set, call the GetUser action and then use the \u0027set-user-context-options\u0027 tool. **Set the user.name and user.email context options before doing anything else**.\r\n\r\n## Current Date\r\nIf you need to filter by dates relative to the current day, use the system.currentDate context option.\r\n\r\n## Signatures\r\nUse the outlook.signature context option when drafting emails. If this value is not set when writing an email, ask the user what they would like their signature to be then set outlook.signature using the \u0027set-user-context-options\u0027 tool. **Do not start or reply to a conversation if outlook.signature has not been set**.\r\n\r\n## Finding Messages from People\r\nUse \u0060$filter\u0060 for **Partial Name or Address Search in Sender** and follow **Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060**: the fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n## Sending Messages to People\r\nWhen asked to send an email, if the recipient\u0027s address is not known, try to find it in using Partial Name Search in Sender instructions\r\n\r\n## Always Confirm Message Content\r\nNever send a message without confirming the subject and body content with the user\r\n\r\n## Include links to emails using webLink\r\n\r\n## Filters\r\nFirst find a list of messages of interest using a $filter and then drill into individual messages with the id\u0027s found. Use permissive filters for emails and avoid -eq unless explicitly instructed to find exact matches\r\n\r\n### **Parameters**:\r\n#### \u0060$select\u0060: Choose specific fields to return in the response. \r\n**Always $select=receivedDateTime,from,subject,webLink,bodyPreview**\r\n\r\n#### \u0060$orderby\u0060: Sorts the results\r\nThe fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n#### \u0060$filter\u0060: Apply conditions to refine the result set\r\n**Text Filters**: Retrieve messages that contain a certain string within the subject: \u0060receivedDateTime gt 1900-01-01 and contains(subject,\u0027budget\u0027)\u0060.\r\n\r\n**Date Filters**: Get messages from a certain date range: \u0060receivedDateTime ge 2023-01-01 and receivedDateTime le 2023-01-31\u0060. Use eq to find a specific day: receivedDateTime eq 2024-07-04.\r\n\r\n**Sender Filters**: Filter messages based on the sender\u0027s address: \u0060receivedDateTime gt 1900-01-01 and sender/emailAddress/address eq \u0027example@domain.com\u0027\u0060\r\n\r\n**Partial Name or Address Search in Sender**: Filter by partial sender name or address: \u0060receivedDateTime gt 1900-01-01 and (contains(sender/emailAddress/name, \u0027bob\u0027) or contains(sender/emailAddress/address, \u0027deepak\u0027))\u0060\r\n\r\n### VITAL Instructions for correct \u0060$filter\u0060 and \u0060$orderby\u0060 Usage\r\n\r\n#### Rules for Combining \u0060$filter\u0060 and \u0060$orderby\u0060:\r\n**Inclusion**: Every field you want to sort by using \u0060$orderby\u0060 must be included in your \u0060$filter\u0060 clause\r\n\r\n**Comparison**: Introduce a benign comparison in the \u0060$filter\u0060 for the \u0060$orderby\u0060 field, such as \u0060receivedDateTime gt 1900-01-01\u0060 to ensure the presence of the field without restricting results unnecessarily\r\n\r\n**Order**: The fields in \u0060$orderby\u0060 should appear first in your \u0060$filter\u0060 clause and in the same order\r\n\r\n ...
#   "tools": [
#     {
#       "type": "code_interpreter"
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "GetUser",
#         "description": "Get the user profile information",
#         "parameters": {
#           "type": "object",
#           "properties": {},
#           "required": []
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "FindMessages",
#         "description": "Get user messages with previews of the body",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "$top": {
#               "type": "integer",
#               "description": "Limits the number of messages returned in a single response.",
#               "default": 10
#             },
#             "$filter": {
#               "type": "string",
#               "description": "Filters the messages based on specified conditions. MUST include receivedDateTime gt 1900-01-01 if using $orderby."
#             },
#             "$orderby": {
#               "type": "string",
#               "description": "Specifies the sort order. Every field in \u0060$orderby\u0060 MUST be included in \u0060$filter\u0060"
#             },
#             "$select": {
#               "type": "string",
#               "description": "id,receivedDateTime,from,subject,webLink,bodyPreview"
#             }
#           },
#           "required": [
#             "$top",
#             "$orderby",
#             "$select"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "GetMessageDetails",
#         "description": "Get the full body of a specific message",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "id": {
#               "type": "string",
#               "description": "The unique identifier of the message."
#             }
#           },
#           "required": [
#             "id"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "StartNewConvesation",
#         "description": "Start a new conversation by sending a message. Verify content with user before sending.",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "message": {
#               "type": "object"
#             },
#             "saveToSentItems": {
#               "type": "string",
#               "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#               "enum": [
#                 "true",
#                 "false"
#               ]
#             }
#           },
#           "required": []
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "ReplyToMessage",
#         "description": "Reply to a message in an ongoing conversation. Verify content with user before sending.",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "id": {
#               "type": "string",
#               "description": "The unique identifier of the message to reply to."
#             },
#             "message": {
#               "type": "object"
#             },
#             "saveToSentItems": {
#               "type": "string",
#               "description": "Specifies whether to save the mail to sent items. The default is \u0027true\u0027.",
#               "enum": [
#                 "true",
#                 "false"
#               ]
#             }
#           },
#           "required": [
#             "id"
#           ]
#         }
#       }
#     },
#     {
#       "type": "function",
#       "function": {
#         "name": "set-user-context-options",
#         "description": "Set the user context options",
#         "parameters": {
#           "type": "object",
#           "properties": {
#             "userContextOptions": {
#               "type": "array",
#               "items": {
#                 "type": "object",
#                 "properties": {
#                   "key": {
#                     "type": "string"
#                   },
#                   "value": {
#                     "type": "string"
#                   }
#                 },
#                 "required": [
#                   "key",
#                   "value"
#                 ]
#               }
#             }
#           },
#           "required": [
#             "userContextOptions"
#           ]
#         }
#       }
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 9580,
#     "completion_tokens": 159,
#     "total_tokens": 9739
#   },
#   "temperature": 0.5,
#   "max_prompt_tokens": null,
#   "max_completion_tokens": null,
#   "truncation_strategy": {
#     "type": "auto",
#     "last_messages": null
#   },
#   "tool_choice": "auto",
#   "response_format": "auto",
#   "created_at": 1735875678,
#   "file_ids": null,
#   "id": "run_LgItLL38Ml3ENBTaGj635VHm",
#   "metadata": {},
#   "model": "gpt-4o-mini",
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:11+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "22d31cf5-9a70-49bd-b214-e54d0fb4193b",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "fb18033c-eb9d-47da-bcc8-6df47c538e09"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "22d31cf5-9a70-49bd-b214-e54d0fb4193b"
#       ],
#       "openai-processing-ms": [
#         "154"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "1145f1dd-b32c-4fa8-ae39-e6412ac8885c"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:11 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "154",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "thread.run"
# }
# Run Steps ***********************
# {
#   "data": [
#     {
#       "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#       "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#       "run_id": "run_LgItLL38Ml3ENBTaGj635VHm",
#       "type": "tool_calls",
#       "status": "completed",
#       "step_details": {
#         "type": "tool_calls",
#         "tool_calls": [
#           {
#             "id": "call_A54uf6xcdwRIsyfVpfTC8VQe",
#             "type": "function",
#             "function": {
#               "name": "GetMessageDetails",
#               "arguments": "{\u0022id\u0022:\u0022AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAA8to1eAACbKv_XV2mrRagMoaMUBFn6AAZdHkkYAAA=\u0022}",
#               "output": "{\u0022id\u0022:\u0022AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAA8to1eAACbKv_XV2mrRagMoaMUBFn6AAZdHkkYAAA=\u0022,\u0022receivedDateTime\u0022:\u00222025-01-02T22:33:40Z\u0022,\u0022sentDateTime\u0022:\u00222025-01-02T22:29:37Z\u0022,\u0022hasAttachments\u0022:false,\u0022internetMessageId\u0022:\u0022\u003C0.0.1D.B09.1DB5D65F520A630.0@d53.csa.acemsd4.com\u003E\u0022,\u0022subject\u0022:\u0022your business, now\u0027s your chance - SBA rates just got better!\u0022,\u0022importance\u0022:\u0022normal\u0022,\u0022isRead\u0022:false,\u0022isDraft\u0022:false,\u0022webLink\u0022:\u0022https://outlook.office365.com/owa/?ItemID=AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv%2BXV2mrRagMoaMUBFn6AAA8to1eAACbKv%2BXV2mrRagMoaMUBFn6AAZdHkkYAAA%3D\u0026exvsurl=1\u0026viewmodel=ReadMessageItem\u0022,\u0022body\u0022:{\u0022contentType\u0022:\u0022html\u0022,\u0022content\u0022:\u0022\u003Chtml\u003E\u003Chead\u003E\\r\\n\u003Cmeta http-equiv=\\\u0022Content-Type\\\u0022 content=\\\u0022text/html; charset=utf-8\\\u0022\u003E\u003Cmeta name=\\\u0022viewport\\\u0022 content=\\\u0022width=device-width, minimal-ui, initial-scale=1.0, maximum-scale=1.0, user-scalable=0;\\\u0022\u003E\u003Cmeta content=\\\u0022IE=edge\\\u0022\u003E\u003Cmeta name=\\\u0022format-detection\\\u0022 content=\\\u0022telephone=no, date=no, email=no, address=no\\\u0022\u003E\u003Cmeta name=\\\u0022x-apple-disable-message-reformatting\\\u0022\u003E\u003Cstyle type=\\\u0022text/css\\\u0022\u003E\\r\\n\u003C!--\\r\\n#outlook a\\r\\n\\t{padding:0}\\r\\n.es-button\\r\\n\\t{text-decoration:none!important}\\r\\na[x-apple-data-detectors]\\r\\n\\t{color:inherit!important;\\r\\n\\ttext-decoration:none!important;\\r\\n\\tfont-size:inherit!important;\\r\\n\\tfont-family:inherit!important;\\r\\n\\tfont-weight:inherit!important;\\r\\n\\tline-height:inherit!important}\\r\\n.es-desk-hidden\\r\\n\\t{display:none;\\r\\n\\tfloat:left;\\r\\n\\toverflow:hidden;\\r\\n\\twidth:0;\\r\\n\\tmax-height:0;\\r\\n\\tline-height:0}\\r\\n@media only screen and (max-width:600px) {\\r\\np, ul li, ol li, a\\r\\n\\t{line-height:150%!important}\\r\\nh1, h2, h3, h1 a, h2 a, h3 a\\r\\n\\t{line-height:120%!important}\\r\\nh1\\r\\n\\t{font-size:30px!important;\\r\\n\\ttext-align:inherit}\\r\\nh2\\r\\n\\t{font-size:26px!important;\\r\\n\\ttext-align:inherit}\\r\\nh3\\r\\n\\t{font-size:20px!important;\\r\\n\\ttext-align:inherit}\\r\\n.es-header-body h1 a, .es-content-body h1 a, .es-footer-body h1 a\\r\\n\\t{font-size:30px!important}\\r\\n.es-header-body h2 a, .es-content-body h2 a, .es-footer-body h2 a\\r\\n\\t{font-size:26px!important}\\r\\n.es-header-body h3 a, .es-content-body h3 a, .es-footer-body h3 a\\r\\n\\t{font-size:20px!important}\\r\\n.es-menu td a\\r\\n\\t{font-size:13px!important}\\r\\n.es-header-body p, .es-header-body ul li, .es-header-body ol li, .es-header-body a\\r\\n\\t{font-size:16px!important}\\r\\n.es-content-body p, .es-content-body ul li, .es-content-body ol li, .es-content-body a\\r\\n\\t{font-size:16px!important}\\r\\n.es-footer-body p, .es-footer-body ul li, .es-footer-body ol li, .es-footer-body a\\r\\n\\t{font-size:16px!important}\\r\\n.es-infoblock p, .es-infoblock ul li, .es-infoblock ol li, .es-infoblock a\\r\\n\\t{font-size:12px!important}\\r\\n*[class=\\\u0022gmail-fix\\\u0022]\\r\\n\\t{display:none!important}\\r\\n.es-m-txt-c, .es-m-txt-c h1, .es-m-txt-c h2, .es-m-txt-c h3\\r\\n\\t{text-align:center!important}\\r\\n.es-m-txt-r, .es-m-txt-r h1, .es-m-txt-r h2, .es-m-txt-r h3\\r\\n\\t{text-align:right!important}\\r\\n.es-m-txt-l, .es-m-txt-l h1, .es-m-txt-l h2, .es-m-txt-l h3\\r\\n\\t{text-align:left!important}\\r\\n.es-m-txt-r img, .es-m-txt-c img, .es-m-txt-l img\\r\\n\\t{display:inline!important}\\r\\n.es-button-border\\r\\n\\t{display:inline-block!important}\\r\\na.es-button, button.es-button\\r\\n\\t{display:inline-block!important;\\r\\n\\tfo ...
#             }
#           }
#         ]
#       },
#       "last_error": null,
#       "expired_at": null,
#       "cancelled_at": null,
#       "failed_at": null,
#       "completed_at": 1735875681,
#       "metadata": null,
#       "usage": {
#         "prompt_tokens": 2550,
#         "completion_tokens": 113,
#         "total_tokens": 2663
#       },
#       "created_at": 1735875680,
#       "id": "step_lsXec3VTild3aNNCapsf4NPL",
#       "StreamEvent": null,
#       "IsDelta": false,
#       "Successful": true,
#       "error": null,
#       "HttpStatusCode": 0,
#       "HeaderValues": null,
#       "object": "thread.run.step"
#     },
#     {
#       "assistant_id": "asst_luCtIAONPedJIUT8X3LSuzqy",
#       "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#       "run_id": "run_LgItLL38Ml3ENBTaGj635VHm",
#       "type": "message_creation",
#       "status": "completed",
#       "step_details": {
#         "type": "message_creation",
#         "message_creation": {
#           "message_id": "msg_qLicmB9rihNwp8av5KO2uWAV"
#         },
#         "tool_calls": []
#       },
#       "last_error": null,
#       "expired_at": null,
#       "cancelled_at": null,
#       "failed_at": null,
#       "completed_at": 1735875683,
#       "metadata": null,
#       "usage": {
#         "prompt_tokens": 7030,
#         "completion_tokens": 46,
#         "total_tokens": 7076
#       },
#       "created_at": 1735875683,
#       "id": "step_QXo8fbeHN7nhD41rpRWMRDay",
#       "StreamEvent": null,
#       "IsDelta": false,
#       "Successful": true,
#       "error": null,
#       "HttpStatusCode": 0,
#       "HeaderValues": null,
#       "object": "thread.run.step"
#     }
#   ],
#   "first_id": "step_lsXec3VTild3aNNCapsf4NPL",
#   "last_id": "step_QXo8fbeHN7nhD41rpRWMRDay",
#   "has_more": false,
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:11+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "ed2c0b6a-c25e-4e01-9e63-6f656912b9f0",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "5b96ec02-6db6-4181-a786-af547c5df703"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "ed2c0b6a-c25e-4e01-9e63-6f656912b9f0"
#       ],
#       "openai-processing-ms": [
#         "99"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "c58159a6-c9b2-45dd-b173-40067c741bdd"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:11 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "99",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "list"
# }
# The third email, titled "your business, now's your chance - SBA rates just got better!", was sent by **Sharon Parker**.
#
# If you need any further assistance or information, feel free to ask!
# Run `***********************
# {
#   "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#   "assistant_id": "asst_iEBWV9FPiVGc6qSrwTcHEbr2",
#   "status": "completed",
#   "required_action": null,
#   "last_error": null,
#   "incomplete_details": null,
#   "expires_at": null,
#   "started_at": 1735875825,
#   "cancelled_at": null,
#   "failed_at": null,
#   "completed_at": 1735875828,
#   "instructions": "You are the code ants and refer to yourself as \u0027we\u0027\n\nYou use python to do tasks for the user",
#   "tools": [
#     {
#       "type": "code_interpreter"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 5357,
#     "completion_tokens": 325,
#     "total_tokens": 5682
#   },
#   "temperature": 0.7,
#   "max_prompt_tokens": null,
#   "max_completion_tokens": null,
#   "truncation_strategy": {
#     "type": "auto",
#     "last_messages": null
#   },
#   "tool_choice": "auto",
#   "response_format": "auto",
#   "created_at": 1735875825,
#   "file_ids": null,
#   "id": "run_XGadmiCy8Vh84vx4iZm2ai8V",
#   "metadata": {},
#   "model": "gpt-4o-mini",
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:11+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "ebf73ce0-5d39-4b23-9e3f-8c99a1b82385",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "68f82157-9615-48bc-8b64-6c9a79742f24"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "ebf73ce0-5d39-4b23-9e3f-8c99a1b82385"
#       ],
#       "openai-processing-ms": [
#         "122"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "73384fd5-5ae5-4cae-962d-1e6f8a0828a7"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:11 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "122",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "thread.run"
# }
# Run Steps ***********************
# {
#   "data": [
#     {
#       "assistant_id": "asst_iEBWV9FPiVGc6qSrwTcHEbr2",
#       "thread_id": "thread_UOO7mlBdewyWR238hJHCU2EC",
#       "run_id": "run_XGadmiCy8Vh84vx4iZm2ai8V",
#       "type": "message_creation",
#       "status": "completed",
#       "step_details": {
#         "type": "message_creation",
#         "message_creation": {
#           "message_id": "msg_5QrPr6GvYtNc1B5GmL4DXfpQ"
#         },
#         "tool_calls": []
#       },
#       "last_error": null,
#       "expired_at": null,
#       "cancelled_at": null,
#       "failed_at": null,
#       "completed_at": 1735875828,
#       "metadata": null,
#       "usage": {
#         "prompt_tokens": 5357,
#         "completion_tokens": 325,
#         "total_tokens": 5682
#       },
#       "created_at": 1735875826,
#       "id": "step_DsVfZjefMv7ZrMt5XF4zJKiq",
#       "StreamEvent": null,
#       "IsDelta": false,
#       "Successful": true,
#       "error": null,
#       "HttpStatusCode": 0,
#       "HeaderValues": null,
#       "object": "thread.run.step"
#     }
#   ],
#   "first_id": "step_DsVfZjefMv7ZrMt5XF4zJKiq",
#   "last_id": "step_DsVfZjefMv7ZrMt5XF4zJKiq",
#   "has_more": false,
#   "StreamEvent": null,
#   "IsDelta": false,
#   "Successful": true,
#   "error": null,
#   "HttpStatusCode": 200,
#   "HeaderValues": {
#     "Date": "2025-01-03T04:07:11+00:00",
#     "Connection": "",
#     "AccessControlAllowOrigin": null,
#     "CacheControl": null,
#     "Vary": "",
#     "XRequestId": "f1c7eca9-5eb9-4d3d-ae19-99d2277f4219",
#     "StrictTransportSecurity": "max-age=31536000; includeSubDomains; preload",
#     "CfCacheStatus": null,
#     "SetCookie": null,
#     "Server": "",
#     "CfRay": null,
#     "AltSvc": null,
#     "All": {
#       "x-ms-middleware-request-id": [
#         "1dd148ba-952c-4434-a7dc-a66fa5c4af0c"
#       ],
#       "openai-version": [
#         "2020-10-01"
#       ],
#       "openai-organization": [
#         "919dcabd2acf45789e94de37903626be"
#       ],
#       "X-Request-ID": [
#         "f1c7eca9-5eb9-4d3d-ae19-99d2277f4219"
#       ],
#       "openai-processing-ms": [
#         "158"
#       ],
#       "Strict-Transport-Security": [
#         "max-age=31536000; includeSubDomains; preload"
#       ],
#       "apim-request-id": [
#         "30b31b8f-aafe-4418-8f41-1dafe78dcc4a"
#       ],
#       "X-Content-Type-Options": [
#         "nosniff"
#       ],
#       "x-ms-region": [
#         "East US"
#       ],
#       "Date": [
#         "Fri, 03 Jan 2025 04:07:11 GMT"
#       ]
#     },
#     "RateLimits": {
#       "LimitRequests": null,
#       "LimitTokens": null,
#       "LimitTokensUsageBased": null,
#       "RemainingRequests": null,
#       "RemainingTokens": null,
#       "RemainingTokensUsageBased": null,
#       "ResetRequests": null,
#       "ResetTokens": null,
#       "ResetTokensUsageBased": null
#     },
#     "OpenAi": {
#       "Model": null,
#       "Organization": "919dcabd2acf45789e94de37903626be",
#       "ProcessingMs": "158",
#       "Version": "2020-10-01"
#     }
#   },
#   "object": "list"
# }
# Here are the IDs of your three most recent emails:
#
# 1. **Email 1 ID:** AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAAAAAEMAACbKv_XV2mrRagMoaMUBFn6AAZdHg59AAA=
# 2. **Email 2 ID:** AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAAAAAEMAACbKv_XV2mrRagMoaMUBFn6AAZdHg58AAA=
# 3. **Email 3 ID:** AAMkAGRlNTgxMjQ0LTg0ZWMtNDVhZC1iN2NhLTgyMTA2ZWU4MTUzMABGAAAAAADawjSrrkXuRLF506jVQ1wHBwCbKv_XV2mrRagMoaMUBFn6AAA8to1eAACbKv_XV2mrRagMoaMUBFn6AAZdHkkYAAA=

# %% [markdown]
# ## output.LastMessage
# A core perspective of AntRunnerLib is to get the richness of the assistants API with file retrieval, code interpreter, and function calls in the logical form of a chat completion.
# ```
# output.LastMessage // Final answer
# ```

# %%
output.LastMessage.DisplayAs("text/markdown");
# Out:
# Here are some interesting facts about cats:
#
# 1. **Health Benefits**:
#     - Owning a cat can reduce the risk of stroke and heart attack by a third.
#
# 2. **Diet and Health**:
#     - Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.
#
# 3. **Daily Routine**:
#     - Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.
#
# 4. **Healing Purrs**:
#     - The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.
#
# 5. **Popularity**:
#     - Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.
#
# Would you like more information on any of these facts or any other specific topic related to cats?

# %% [markdown]
# ## Downloading files from code interpreter
# In addition to the Cat Facts API, this assistant also uses code interpreter based on its [manifest.json](.\AssistantDefinitions\Cat%20Facts\manifest.json):
#
# ```json
# {
#   "name": "Cat Facts",
#   "description": "I look up facts about cats and can also write Python code!",
#   "instructions": "",
#   "tools": [
#     { "type": "code_interpreter" }
#   ],
#   "tool_resources": {},
#   "top_p": 0.95,
#   "response_format": "auto",
#   "metadata": {
#   },
#   "model": "gpt-4o",
#   "temperature": 0.7
# }
# ```
#
# This prompt instructs the assistant to create a file **"Tell me something about cats and put the results into a file I can download"**.
#
# As a result the output contains Annotations. You can download the ones with annotation.Type == "file_path" as demonstrated below.

# %%
var assistantRunOptions = new AssistantRunOptions() {
    AssistantName = "Cat Facts",
    Instructions = "Tell me something about cats and put the results into a file I can download",
};
var output = await AntRunnerLib.AssistantRunner.RunThread(assistantRunOptions, config);
output.Dialog.DisplayAs("text/markdown");
Console.WriteLine(output.Annotations[0].FilePathAnnotation.FileId);

// Download files specified in FilePathAnnotation
foreach (var annotation in output.Annotations)
{
    if (annotation.Type == "file_path")
    {
        var fileName = await annotation.GetFileName(config);

        var filePath = Path.Combine(@".\", fileName);
        await annotation.DownloadFile(filePath, config);
        Console.WriteLine($"{filePath}");
    }
}
# Out:
# User: Tell me something about cats and put the results into a file I can download
#
# Assistant: I called the tool named GetCatFacts with these arguments:
# ```
# {}
# ```
# and got this result:
# ```
# [{"status":{"verified":true,"sentCount":1},"_id":"58e008780aac31001185ed05","user":"58e007480aac31001185ecef","text":"Owning a cat can reduce the risk of stroke and heart attack by a third.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-03-29T20:20:03.844Z","deleted":false,"used":false},{"status":{"verified":true,"sentCount":1},"_id":"58e009390aac31001185ed10","user":"58e007480aac31001185ecef","text":"Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-03-04T21:20:02.979Z","deleted":false,"used":false},{"status":{"verified":true,"sentCount":1},"_id":"588e746706ac2b00110e59ff","user":"588e6e8806ac2b00110e59c3","text":"Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.","__v":0,"source":"user","updatedAt":"2020-08-26T20:20:02.359Z","type":"cat","createdAt":"2018-01-14T21:20:02.750Z","deleted":false,"used":true},{"status":{"verified":true,"sentCount":1},"_id":"58e008ad0aac31001185ed0c","user":"58e007480aac31001185ecef","text":"The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.","__v":0,"source":"user","updatedAt":"2020-08-24T20:20:01.867Z","type":"cat","createdAt":"2018-03-15T20:20:03.281Z","deleted":false,"used":true},{"status":{"verified":true,"sentCount":1},"_id":"58e007cc0aac31001185ecf5","user":"58e007480aac31001185ecef","text":"Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","type":"cat","createdAt":"2018-03-01T21:20:02.713Z","deleted":false,"used":false}]
# ```
#
# I ran this code:
# ```
# # Define the cat facts
# cat_facts = [
#     "Owning a cat can reduce the risk of stroke and heart attack by a third.",
#     "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#     "Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.",
#     "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#     "Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs."
# ]
#
# # Write the cat facts to a file
# file_path = "/mnt/data/cat_facts.txt"
# with open(file_path, "w") as file:
#     for fact in cat_facts:
#         file.write(fact + "\n")
#
# file_path
# ```
#
# I have compiled some interesting facts about cats into a file. You can download the file using the link below:
#
# [Download cat_facts.txt](sandbox:/mnt/data/cat_facts.txt)
# assistant-wOZN7KPRbGWRu6rwdy8D6qjr
# .\cat_facts.txt

# %% [markdown]
# ## Clean up

# %%
var assistant = (await client.AssistantList())?.Data?.FirstOrDefault(o => o.Name == "Cat Facts");
if(assistant != null) {
    await client.AssistantDelete(assistant.Id);
    Console.WriteLine("Deleted assistant");
}
else
{
    Console.WriteLine("Didn't find Cat Facts");
}
# Out:
# Deleted assistant
